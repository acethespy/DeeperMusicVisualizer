# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Joe's cell
DRIVE_PATH = '/content/drive/MyDrive/Cal/Colab/DeepMusicVisualizer'

# %%
# Richard's cell
DRIVE_PATH = 'TODO'

# %%
SYM_PATH = '/content/DeepMusicVisualizer'
if not os.path.exists(SYM_PATH):
  # !ln -s $DRIVE_PATH $SYM_PATH

# %%
import sys
# !pip install boto3
import boto3
from botocore.exceptions import NoCredentialsError

# %%
s3 = boto3.client('s3', aws_access_key_id='ASIA553NMCCAJKQ6RPWS', aws_secret_access_key="/zof47vExlsxxi25DlwNvx6/PsoWpd/bLb8nOB2i", aws_session_token="...")

SONGS_DIR = os.path.join(SYM_PATH, 'results/songs')
songs = []
unidentified = []
for name in os.listdir(SONGS_DIR):
  if '.mp4' in name:
    songs.append(name)
    try:
      local_file = os.path.join(SONGS_DIR, name)
      s3_file = os.path.join('songs', name)
      s3.upload_file(local_file, 'deepmusicvisualizer', s3_file)
    except FileNotFoundError:
      print("The file was not found")
    except NoCredentialsError:
      print("Credentials not available")
  else:
    unidentified.append(name)
